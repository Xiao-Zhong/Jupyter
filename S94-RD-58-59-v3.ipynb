# %%
using CSV
using DataFrames
using Plots

# %% [markdown]
# # Read alignment tables of R&D58

# %%
#df = CSV.read("file.csv", DataFrame) ## a faster way
rd58_df = DataFrame(CSV.File("S94_RD58_stat_summary.xls"))
rd58_50bp_df = DataFrame(CSV.File("S94_RD58_50bp_stat_summary.xls"))
rd58_50bp_1m_df = DataFrame(CSV.File("S94_RD58_50bp_1M_stat_summary.xls"))
rd58_50bp_2m_df = DataFrame(CSV.File("S94_RD58_50bp_2M_stat_summary.xls"))
rd58_50bp_5m_df = DataFrame(CSV.File("S94_RD58_50bp_5M_stat_summary.xls"))
# Out:
# 5×25 DataFrame
#  Row │ sample                      species       reads    ribo_reads  ercc_rea ⋯
#      │ String                      String        Int64    String      String   ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ RD58-100pg_S7_50bp_5M_L002  Mus_musculus  5000000  NA          NA       ⋯
#    2 │ RD58-10ng_S10_50bp_5M_L002  Mus_musculus  5000000  NA          NA
#    3 │ RD58-10pg_S6_50bp_5M_L002   Mus_musculus  2216467  NA          NA
#    4 │ RD58-1ng_S9_50bp_5M_L002    Mus_musculus  5000000  NA          NA
#    5 │ RD58-500pg_S8_50bp_5M_L002  Mus_musculus  5000000  NA          NA       ⋯
#                                                               21 columns omitted

# %% [markdown]
# # A summary table of R&D58

# %%
#merge tables
rd58_df = vcat(rd58_df, rd58_50bp_df, rd58_50bp_1m_df, rd58_50bp_2m_df, rd58_50bp_5m_df)
#remove "_L002"
rd58_df[!, "sample"] = replace.(rd58_df[!, "sample"], r"_L002" => "")
#sort rows in the predefined order: S6, S7,..., S10
myOrder = [
    "RD58-10pg_S6", 
    "RD58-100pg_S7", 
    "RD58-500pg_S8", 
    "RD58-1ng_S9", 
    "RD58-10ng_S10",
    
    "RD58-10pg_S6_50bp", 
    "RD58-100pg_S7_50bp", 
    "RD58-500pg_S8_50bp", 
    "RD58-1ng_S9_50bp",
    "RD58-10ng_S10_50bp",
    
    "RD58-10pg_S6_50bp_1M", 
    "RD58-100pg_S7_50bp_1M", 
    "RD58-500pg_S8_50bp_1M", 
    "RD58-1ng_S9_50bp_1M", 
    "RD58-10ng_S10_50bp_1M",
    
    "RD58-10pg_S6_50bp_2M", 
    "RD58-100pg_S7_50bp_2M", 
    "RD58-500pg_S8_50bp_2M", 
    "RD58-1ng_S9_50bp_2M", 
    "RD58-10ng_S10_50bp_2M", 
    
    "RD58-100pg_S7_50bp_5M", 
    "RD58-500pg_S8_50bp_5M", 
    "RD58-1ng_S9_50bp_5M", 
    "RD58-10ng_S10_50bp_5M"
]
rd58_df = rd58_df[indexin(myOrder, rd58_df.sample),:]
# Out:
# 24×25 DataFrame
#  Row │ sample                 species       reads     ribo_reads  ercc_reads   ⋯
#      │ String                 String        Int64     String      String       ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ RD58-10pg_S6           Mus_musculus   2216467  NA          NA           ⋯
#    2 │ RD58-100pg_S7          Mus_musculus   6096257  NA          NA
#    3 │ RD58-500pg_S8          Mus_musculus   6870582  NA          NA
#    4 │ RD58-1ng_S9            Mus_musculus   5381029  NA          NA
#    5 │ RD58-10ng_S10          Mus_musculus  12590390  NA          NA           ⋯
#    6 │ RD58-10pg_S6_50bp      Mus_musculus   2216467  NA          NA
#    7 │ RD58-100pg_S7_50bp     Mus_musculus   6096257  NA          NA
#    8 │ RD58-500pg_S8_50bp     Mus_musculus   6870582  NA          NA
#    9 │ RD58-1ng_S9_50bp       Mus_musculus   5381029  NA          NA           ⋯
#   10 │ RD58-10ng_S10_50bp     Mus_musculus  12590390  NA          NA
#   11 │ RD58-10pg_S6_50bp_1M   Mus_musculus   1000000  NA          NA
#   ⋮  │           ⋮                 ⋮           ⋮          ⋮           ⋮        ⋱
#   15 │ RD58-10ng_S10_50bp_1M  Mus_musculus   1000000  NA          NA
#   16 │ RD58-10pg_S6_50bp_2M   Mus_musculus   2000000  NA          NA           ⋯
#   17 │ RD58-100pg_S7_50bp_2M  Mus_musculus   2000000  NA          NA
#   18 │ RD58-500pg_S8_50bp_2M  Mus_musculus   2000000  NA          NA
#   19 │ RD58-1ng_S9_50bp_2M    Mus_musculus   2000000  NA          NA
#   20 │ RD58-10ng_S10_50bp_2M  Mus_musculus   2000000  NA          NA           ⋯
#   21 │ RD58-100pg_S7_50bp_5M  Mus_musculus   5000000  NA          NA
#   22 │ RD58-500pg_S8_50bp_5M  Mus_musculus   5000000  NA          NA
#   23 │ RD58-1ng_S9_50bp_5M    Mus_musculus   5000000  NA          NA
#   24 │ RD58-10ng_S10_50bp_5M  Mus_musculus   5000000  NA          NA           ⋯
#                                                    20 columns and 3 rows omitted

# %% [markdown]
# # Plots of R&D58

# %%
#insert a row for the missing sample, so there are 25 rows = 5 groups * 5 treatments,
#also make it easier to add the columns as below
new_row = pushfirst!(Array{Any, 1}(missing, ncol(rd58_df)-1), "RD58-10pg_S6_50bp_5M")
allowmissing!(rd58_df)
insert!.(eachcol(rd58_df), 21, new_row)
rd58_df
# Out:
# 25×25 DataFrame
#  Row │ sample                 species       reads     ribo_reads  ercc_reads   ⋯
#      │ String?                String?       Int64?    String?     String?      ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ RD58-10pg_S6           Mus_musculus   2216467  NA          NA           ⋯
#    2 │ RD58-100pg_S7          Mus_musculus   6096257  NA          NA
#    3 │ RD58-500pg_S8          Mus_musculus   6870582  NA          NA
#    4 │ RD58-1ng_S9            Mus_musculus   5381029  NA          NA
#    5 │ RD58-10ng_S10          Mus_musculus  12590390  NA          NA           ⋯
#    6 │ RD58-10pg_S6_50bp      Mus_musculus   2216467  NA          NA
#    7 │ RD58-100pg_S7_50bp     Mus_musculus   6096257  NA          NA
#    8 │ RD58-500pg_S8_50bp     Mus_musculus   6870582  NA          NA
#    9 │ RD58-1ng_S9_50bp       Mus_musculus   5381029  NA          NA           ⋯
#   10 │ RD58-10ng_S10_50bp     Mus_musculus  12590390  NA          NA
#   11 │ RD58-10pg_S6_50bp_1M   Mus_musculus   1000000  NA          NA
#   ⋮  │           ⋮                 ⋮           ⋮          ⋮           ⋮        ⋱
#   16 │ RD58-10pg_S6_50bp_2M   Mus_musculus   2000000  NA          NA
#   17 │ RD58-100pg_S7_50bp_2M  Mus_musculus   2000000  NA          NA           ⋯
#   18 │ RD58-500pg_S8_50bp_2M  Mus_musculus   2000000  NA          NA
#   19 │ RD58-1ng_S9_50bp_2M    Mus_musculus   2000000  NA          NA
#   20 │ RD58-10ng_S10_50bp_2M  Mus_musculus   2000000  NA          NA
#   21 │ RD58-10pg_S6_50bp_5M   missing        missing  missing     missing      ⋯
#   22 │ RD58-100pg_S7_50bp_5M  Mus_musculus   5000000  NA          NA
#   23 │ RD58-500pg_S8_50bp_5M  Mus_musculus   5000000  NA          NA
#   24 │ RD58-1ng_S9_50bp_5M    Mus_musculus   5000000  NA          NA
#   25 │ RD58-10ng_S10_50bp_5M  Mus_musculus   5000000  NA          NA           ⋯
#                                                    20 columns and 4 rows omitted

# %%
#insert a column for the groups
treatments = ["all", "50bp", "50bp-1M", "50bp-2M", "50bp-5M"]
cases = [i for i in treatments for j in 1:5]
insertcols!(rd58_df, 2, "treatment" => cases)
rd58_df
# Out:
# 25×26 DataFrame
#  Row │ sample                 treatment  species       reads     ribo_reads  e ⋯
#      │ String?                String     String?       Int64?    String?     S ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ RD58-10pg_S6           all        Mus_musculus   2216467  NA          N ⋯
#    2 │ RD58-100pg_S7          all        Mus_musculus   6096257  NA          N
#    3 │ RD58-500pg_S8          all        Mus_musculus   6870582  NA          N
#    4 │ RD58-1ng_S9            all        Mus_musculus   5381029  NA          N
#    5 │ RD58-10ng_S10          all        Mus_musculus  12590390  NA          N ⋯
#    6 │ RD58-10pg_S6_50bp      50bp       Mus_musculus   2216467  NA          N
#    7 │ RD58-100pg_S7_50bp     50bp       Mus_musculus   6096257  NA          N
#    8 │ RD58-500pg_S8_50bp     50bp       Mus_musculus   6870582  NA          N
#    9 │ RD58-1ng_S9_50bp       50bp       Mus_musculus   5381029  NA          N ⋯
#   10 │ RD58-10ng_S10_50bp     50bp       Mus_musculus  12590390  NA          N
#   11 │ RD58-10pg_S6_50bp_1M   50bp-1M    Mus_musculus   1000000  NA          N
#   ⋮  │           ⋮                ⋮           ⋮           ⋮          ⋮         ⋱
#   16 │ RD58-10pg_S6_50bp_2M   50bp-2M    Mus_musculus   2000000  NA          N
#   17 │ RD58-100pg_S7_50bp_2M  50bp-2M    Mus_musculus   2000000  NA          N ⋯
#   18 │ RD58-500pg_S8_50bp_2M  50bp-2M    Mus_musculus   2000000  NA          N
#   19 │ RD58-1ng_S9_50bp_2M    50bp-2M    Mus_musculus   2000000  NA          N
#   20 │ RD58-10ng_S10_50bp_2M  50bp-2M    Mus_musculus   2000000  NA          N
#   21 │ RD58-10pg_S6_50bp_5M   50bp-5M    missing        missing  missing     m ⋯
#   22 │ RD58-100pg_S7_50bp_5M  50bp-5M    Mus_musculus   5000000  NA          N
#   23 │ RD58-500pg_S8_50bp_5M  50bp-5M    Mus_musculus   5000000  NA          N
#   24 │ RD58-1ng_S9_50bp_5M    50bp-5M    Mus_musculus   5000000  NA          N
#   25 │ RD58-10ng_S10_50bp_5M  50bp-5M    Mus_musculus   5000000  NA          N ⋯
#                                                    21 columns and 4 rows omitted

# %%
#insert a column for the treatments
inputs = ["10pg", "100pg", "500pg", "1ng", "10ng"]
input_column = repeat(inputs, 5)
insertcols!(rd58_df, 3, "input" => input_column)
rd58_df
# Out:
# 25×27 DataFrame
#  Row │ sample                 treatment  input   species       reads     ribo_ ⋯
#      │ String?                String     String  String?       Int64?    Strin ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ RD58-10pg_S6           all        10pg    Mus_musculus   2216467  NA    ⋯
#    2 │ RD58-100pg_S7          all        100pg   Mus_musculus   6096257  NA
#    3 │ RD58-500pg_S8          all        500pg   Mus_musculus   6870582  NA
#    4 │ RD58-1ng_S9            all        1ng     Mus_musculus   5381029  NA
#    5 │ RD58-10ng_S10          all        10ng    Mus_musculus  12590390  NA    ⋯
#    6 │ RD58-10pg_S6_50bp      50bp       10pg    Mus_musculus   2216467  NA
#    7 │ RD58-100pg_S7_50bp     50bp       100pg   Mus_musculus   6096257  NA
#    8 │ RD58-500pg_S8_50bp     50bp       500pg   Mus_musculus   6870582  NA
#    9 │ RD58-1ng_S9_50bp       50bp       1ng     Mus_musculus   5381029  NA    ⋯
#   10 │ RD58-10ng_S10_50bp     50bp       10ng    Mus_musculus  12590390  NA
#   11 │ RD58-10pg_S6_50bp_1M   50bp-1M    10pg    Mus_musculus   1000000  NA
#   ⋮  │           ⋮                ⋮        ⋮          ⋮           ⋮          ⋮ ⋱
#   16 │ RD58-10pg_S6_50bp_2M   50bp-2M    10pg    Mus_musculus   2000000  NA
#   17 │ RD58-100pg_S7_50bp_2M  50bp-2M    100pg   Mus_musculus   2000000  NA    ⋯
#   18 │ RD58-500pg_S8_50bp_2M  50bp-2M    500pg   Mus_musculus   2000000  NA
#   19 │ RD58-1ng_S9_50bp_2M    50bp-2M    1ng     Mus_musculus   2000000  NA
#   20 │ RD58-10ng_S10_50bp_2M  50bp-2M    10ng    Mus_musculus   2000000  NA
#   21 │ RD58-10pg_S6_50bp_5M   50bp-5M    10pg    missing        missing  missi ⋯
#   22 │ RD58-100pg_S7_50bp_5M  50bp-5M    100pg   Mus_musculus   5000000  NA
#   23 │ RD58-500pg_S8_50bp_5M  50bp-5M    500pg   Mus_musculus   5000000  NA
#   24 │ RD58-1ng_S9_50bp_5M    50bp-5M    1ng     Mus_musculus   5000000  NA
#   25 │ RD58-10ng_S10_50bp_5M  50bp-5M    10ng    Mus_musculus   5000000  NA    ⋯
#                                                    22 columns and 4 rows omitted

# %%
#remove the 'missing' row added above to make the follwoing plotting easier
rd58_df2 = rd58_df[Not(21), :]
# Out:
# 24×27 DataFrame
#  Row │ sample                 treatment  input   species       reads     ribo_ ⋯
#      │ String?                String     String  String?       Int64?    Strin ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ RD58-10pg_S6           all        10pg    Mus_musculus   2216467  NA    ⋯
#    2 │ RD58-100pg_S7          all        100pg   Mus_musculus   6096257  NA
#    3 │ RD58-500pg_S8          all        500pg   Mus_musculus   6870582  NA
#    4 │ RD58-1ng_S9            all        1ng     Mus_musculus   5381029  NA
#    5 │ RD58-10ng_S10          all        10ng    Mus_musculus  12590390  NA    ⋯
#    6 │ RD58-10pg_S6_50bp      50bp       10pg    Mus_musculus   2216467  NA
#    7 │ RD58-100pg_S7_50bp     50bp       100pg   Mus_musculus   6096257  NA
#    8 │ RD58-500pg_S8_50bp     50bp       500pg   Mus_musculus   6870582  NA
#    9 │ RD58-1ng_S9_50bp       50bp       1ng     Mus_musculus   5381029  NA    ⋯
#   10 │ RD58-10ng_S10_50bp     50bp       10ng    Mus_musculus  12590390  NA
#   11 │ RD58-10pg_S6_50bp_1M   50bp-1M    10pg    Mus_musculus   1000000  NA
#   ⋮  │           ⋮                ⋮        ⋮          ⋮           ⋮          ⋮ ⋱
#   15 │ RD58-10ng_S10_50bp_1M  50bp-1M    10ng    Mus_musculus   1000000  NA
#   16 │ RD58-10pg_S6_50bp_2M   50bp-2M    10pg    Mus_musculus   2000000  NA    ⋯
#   17 │ RD58-100pg_S7_50bp_2M  50bp-2M    100pg   Mus_musculus   2000000  NA
#   18 │ RD58-500pg_S8_50bp_2M  50bp-2M    500pg   Mus_musculus   2000000  NA
#   19 │ RD58-1ng_S9_50bp_2M    50bp-2M    1ng     Mus_musculus   2000000  NA
#   20 │ RD58-10ng_S10_50bp_2M  50bp-2M    10ng    Mus_musculus   2000000  NA    ⋯
#   21 │ RD58-100pg_S7_50bp_5M  50bp-5M    100pg   Mus_musculus   5000000  NA
#   22 │ RD58-500pg_S8_50bp_5M  50bp-5M    500pg   Mus_musculus   5000000  NA
#   23 │ RD58-1ng_S9_50bp_5M    50bp-5M    1ng     Mus_musculus   5000000  NA
#   24 │ RD58-10ng_S10_50bp_5M  50bp-5M    10ng    Mus_musculus   5000000  NA    ⋯
#                                                    22 columns and 3 rows omitted

# %%
using StatsPlots
gr()
# Out:
# Plots.GRBackend()

# %%
#filter(:treatment => ==("all"), rd58_df2)
newColumn = parse.(Float64, replace.(rd58_df2[!, "uniquely_mapped"], r"%" => ""))
lastGroup = pushfirst!(Array{Any, 1}(newColumn[21:24]), missing)

@df rd58_df2 plot(inputs,
    [newColumn[1:5], newColumn[6:10], newColumn[11:15], newColumn[16:20], lastGroup],
    label = ["all" "50bp" "50bp-1M" "50bp-2M" "50bp-5M"],
    shape = [:circle :star5 :utriangle :rect :diamond ],
    legend = :bottomright,
    size=(900,700),
    xlabel = "RNA input", ylabel = "Uniquely mapped(%)",
    xtickfontsize=12, ytickfontsize=12,
    guidefont=font(15),
    m = (1, 10)
)

# %%
newColumn = parse.(Float64, replace.(rd58_df2[!, "duplicate_rate"], r"%" => ""))
lastGroup = pushfirst!(Array{Any, 1}(newColumn[21:24]), missing)

@df rd58_df2 plot(inputs,
    [newColumn[1:5], newColumn[6:10], newColumn[11:15], newColumn[16:20], lastGroup],
    label = ["all" "50bp" "50bp-1M" "50bp-2M" "50bp-5M"],
    shape = [:circle :star5 :utriangle :rect :diamond ],
    legend = :bottomleft,
    size=(900,700),
    xlabel = "RNA input", 
    ylabel = "Duplicate rate(%)",
    xtickfontsize=12, ytickfontsize=12,
    guidefont=font(15),
    m = (1, 10)
)

# %%
#filter(:treatment => ==("all"), rd58_df2)
newColumn = rd58_df2[!, "protein-coding_gene_mapped(21859)"]
lastGroup = pushfirst!(Array{Any, 1}(newColumn[21:24]), missing)

@df rd58_df2 plot(inputs,
    [newColumn[1:5], newColumn[6:10], newColumn[11:15], newColumn[16:20], lastGroup],
    label = ["all" "50bp" "50bp-1M" "50bp-2M" "50bp-5M"],
    shape = [:circle :star5 :utriangle :rect :diamond ],
    #color = [:white :white :white :white :white],
    legend = :bottomright,
    size=(900,700),
    xlabel = "RNA input", 
    ylabel = "Total genes detected",
    xtickfontsize=12, ytickfontsize=12,
    guidefont=font(15),
    m = (1, 10)
)

# %% [markdown]
# # Read alignment tables of R&D59

# %%
#do the work for R&D59 as above
rd59_df = DataFrame(CSV.File("S94_RD59_stat_summary.xls"))
rd59_50bp_df = DataFrame(CSV.File("S94_RD59_50bp_stat_summary.xls"))
rd59_50bp_1m_df = DataFrame(CSV.File("S94_RD59_50bp_1M_stat_summary.xls"))
rd59_50bp_2m_df = DataFrame(CSV.File("S94_RD59_50bp_2M_stat_summary.xls"))
rd59_50bp_5m_df = DataFrame(CSV.File("S94_RD59_50bp_5M_stat_summary.xls"))
# Out:
# 5×25 DataFrame
#  Row │ sample                       species       reads    ribo_reads  ercc_re ⋯
#      │ String                       String        Int64    String      String  ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ RD59-1-ng_S4_50bp_5M_L002    Homo_sapiens  5000000  NA          NA      ⋯
#    2 │ RD59-10-pg_S1_50bp_5M_L002   Homo_sapiens  5000000  NA          NA
#    3 │ RD59-100-pg_S2_50bp_5M_L002  Homo_sapiens  5000000  NA          NA
#    4 │ RD59-25-ng_S5_50bp_5M_L002   Homo_sapiens  5000000  NA          NA
#    5 │ RD59-500-pg_S3_50bp_5M_L002  Homo_sapiens  5000000  NA          NA      ⋯
#                                                               21 columns omitted

# %% [markdown]
# # A summary table of R&D59

# %%
rd59_df = vcat(rd59_df, rd59_50bp_df, rd59_50bp_1m_df, rd59_50bp_2m_df, rd59_50bp_5m_df)
rd59_df[!, "sample"]  = replace.(replace.(replace.(rd59_df[!, "sample"], r"_L002" => ""), r"-ng" => "ng"), r"-pg" => "pg")
myOrder2 = [
     "RD59-10pg_S1",
     "RD59-100pg_S2",
     "RD59-500pg_S3",
     "RD59-1ng_S4",
     "RD59-25ng_S5",
    
     "RD59-10pg_S1_50bp",
     "RD59-100pg_S2_50bp",
     "RD59-500pg_S3_50bp",
     "RD59-1ng_S4_50bp",
     "RD59-25ng_S5_50bp",
    
     "RD59-10pg_S1_50bp_1M",
     "RD59-100pg_S2_50bp_1M",
     "RD59-500pg_S3_50bp_1M",
     "RD59-1ng_S4_50bp_1M",
     "RD59-25ng_S5_50bp_1M",

     "RD59-10pg_S1_50bp_2M",
     "RD59-100pg_S2_50bp_2M",
     "RD59-500pg_S3_50bp_2M",
     "RD59-1ng_S4_50bp_2M",
     "RD59-25ng_S5_50bp_2M",

     "RD59-10pg_S1_50bp_5M",
     "RD59-100pg_S2_50bp_5M",
     "RD59-500pg_S3_50bp_5M",
     "RD59-1ng_S4_50bp_5M",
     "RD59-25ng_S5_50bp_5M",
]
rd59_df = rd59_df[indexin(myOrder2, rd59_df.sample),:]
#CSV.write("./S59.txt", rd59_df)
# Out:
# 25×25 DataFrame
#  Row │ sample                 species       reads     ribo_reads  ercc_reads   ⋯
#      │ String                 String        Int64     String      String       ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ RD59-10pg_S1           Homo_sapiens  11787482  NA          NA           ⋯
#    2 │ RD59-100pg_S2          Homo_sapiens  15932075  NA          NA
#    3 │ RD59-500pg_S3          Homo_sapiens   7778651  NA          NA
#    4 │ RD59-1ng_S4            Homo_sapiens   9324827  NA          NA
#    5 │ RD59-25ng_S5           Homo_sapiens  16158726  NA          NA           ⋯
#    6 │ RD59-10pg_S1_50bp      Homo_sapiens  11787482  NA          NA
#    7 │ RD59-100pg_S2_50bp     Homo_sapiens  15932075  NA          NA
#    8 │ RD59-500pg_S3_50bp     Homo_sapiens   7778651  NA          NA
#    9 │ RD59-1ng_S4_50bp       Homo_sapiens   9324827  NA          NA           ⋯
#   10 │ RD59-25ng_S5_50bp      Homo_sapiens  16158726  NA          NA
#   11 │ RD59-10pg_S1_50bp_1M   Homo_sapiens   1000000  NA          NA
#   ⋮  │           ⋮                 ⋮           ⋮          ⋮           ⋮        ⋱
#   16 │ RD59-10pg_S1_50bp_2M   Homo_sapiens   2000000  NA          NA
#   17 │ RD59-100pg_S2_50bp_2M  Homo_sapiens   2000000  NA          NA           ⋯
#   18 │ RD59-500pg_S3_50bp_2M  Homo_sapiens   2000000  NA          NA
#   19 │ RD59-1ng_S4_50bp_2M    Homo_sapiens   2000000  NA          NA
#   20 │ RD59-25ng_S5_50bp_2M   Homo_sapiens   2000000  NA          NA
#   21 │ RD59-10pg_S1_50bp_5M   Homo_sapiens   5000000  NA          NA           ⋯
#   22 │ RD59-100pg_S2_50bp_5M  Homo_sapiens   5000000  NA          NA
#   23 │ RD59-500pg_S3_50bp_5M  Homo_sapiens   5000000  NA          NA
#   24 │ RD59-1ng_S4_50bp_5M    Homo_sapiens   5000000  NA          NA
#   25 │ RD59-25ng_S5_50bp_5M   Homo_sapiens   5000000  NA          NA           ⋯
#                                                    20 columns and 4 rows omitted

# %%
treatments = ["all", "50bp", "50bp-1M", "50bp-2M", "50bp-5M"]
cases = [i for i in treatments for j in 1:5]
insertcols!(rd59_df, 2, "treatment" => cases)

inputs = ["10pg", "100pg", "500pg", "1ng", "25ng"]
input_column = repeat(inputs, 5)
insertcols!(rd59_df, 3, "input" => input_column)
rd59_df
# Out:
# 25×27 DataFrame
#  Row │ sample                 treatment  input   species       reads     ribo_ ⋯
#      │ String                 String     String  String        Int64     Strin ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ RD59-10pg_S1           all        10pg    Homo_sapiens  11787482  NA    ⋯
#    2 │ RD59-100pg_S2          all        100pg   Homo_sapiens  15932075  NA
#    3 │ RD59-500pg_S3          all        500pg   Homo_sapiens   7778651  NA
#    4 │ RD59-1ng_S4            all        1ng     Homo_sapiens   9324827  NA
#    5 │ RD59-25ng_S5           all        25ng    Homo_sapiens  16158726  NA    ⋯
#    6 │ RD59-10pg_S1_50bp      50bp       10pg    Homo_sapiens  11787482  NA
#    7 │ RD59-100pg_S2_50bp     50bp       100pg   Homo_sapiens  15932075  NA
#    8 │ RD59-500pg_S3_50bp     50bp       500pg   Homo_sapiens   7778651  NA
#    9 │ RD59-1ng_S4_50bp       50bp       1ng     Homo_sapiens   9324827  NA    ⋯
#   10 │ RD59-25ng_S5_50bp      50bp       25ng    Homo_sapiens  16158726  NA
#   11 │ RD59-10pg_S1_50bp_1M   50bp-1M    10pg    Homo_sapiens   1000000  NA
#   ⋮  │           ⋮                ⋮        ⋮          ⋮           ⋮          ⋮ ⋱
#   16 │ RD59-10pg_S1_50bp_2M   50bp-2M    10pg    Homo_sapiens   2000000  NA
#   17 │ RD59-100pg_S2_50bp_2M  50bp-2M    100pg   Homo_sapiens   2000000  NA    ⋯
#   18 │ RD59-500pg_S3_50bp_2M  50bp-2M    500pg   Homo_sapiens   2000000  NA
#   19 │ RD59-1ng_S4_50bp_2M    50bp-2M    1ng     Homo_sapiens   2000000  NA
#   20 │ RD59-25ng_S5_50bp_2M   50bp-2M    25ng    Homo_sapiens   2000000  NA
#   21 │ RD59-10pg_S1_50bp_5M   50bp-5M    10pg    Homo_sapiens   5000000  NA    ⋯
#   22 │ RD59-100pg_S2_50bp_5M  50bp-5M    100pg   Homo_sapiens   5000000  NA
#   23 │ RD59-500pg_S3_50bp_5M  50bp-5M    500pg   Homo_sapiens   5000000  NA
#   24 │ RD59-1ng_S4_50bp_5M    50bp-5M    1ng     Homo_sapiens   5000000  NA
#   25 │ RD59-25ng_S5_50bp_5M   50bp-5M    25ng    Homo_sapiens   5000000  NA    ⋯
#                                                    22 columns and 4 rows omitted

# %% [markdown]
# # Plots of S59

# %%
newColumn = parse.(Float64, replace.(rd59_df[!, "uniquely_mapped"], r"%" => ""))

@df rd59_df plot(inputs,
    [newColumn[1:5], newColumn[6:10], newColumn[11:15], newColumn[16:20], newColumn[21:25]],
    label = ["all" "50bp" "50bp-1M" "50bp-2M" "50bp-5M"],
    shape = [:circle :star5 :utriangle :rect :diamond ],
    legend = :bottomleft,
    size=(900,700),
    xlabel = "RNA input", 
    ylabel = "Uniquely mapped(%)",
    xtickfontsize=12, ytickfontsize=12,
    guidefont=font(15),
    m = (1, 10)
)

# %%
newColumn = parse.(Float64, replace.(rd59_df[!, "duplicate_rate"], r"%" => ""))

@df rd59_df plot(inputs,
    [newColumn[1:5], newColumn[6:10], newColumn[11:15], newColumn[16:20], newColumn[21:25]],
    label = ["all" "50bp" "50bp-1M" "50bp-2M" "50bp-5M"],
    shape = [:circle :star5 :utriangle :rect :diamond ],
    size=(900,700),
    legend = :left,
    xlabel = "RNA input", 
    ylabel = "Duplicate rate(%)",
    xtickfontsize=12, ytickfontsize=12,
    guidefont=font(15),
    m = (1, 10)
)

# %%
newColumn = rd59_df[!, "protein-coding_gene_mapped(19954)"]

@df rd59_df plot(inputs,
    [newColumn[1:5], newColumn[6:10], newColumn[11:15], newColumn[16:20], newColumn[21:25]],
    label = ["all" "50bp" "50bp-1M" "50bp-2M" "50bp-5M"],
    shape = [:circle :star5 :utriangle :rect :diamond ],
    legend = :bottomright,
    size=(900,700),
    xlabel = "RNA input", 
    ylabel = "Total genes detected",
    xtickfontsize=12, ytickfontsize=12,
    guidefont=font(15),
    m = (1, 10)
)

# %% [markdown]
# Summary:
# Read length impacts 'unique mapping';
# Read number impacts 'duplicate' and 'genes detected';
# RNA input impacts 'genes detected' as well.

# %% [markdown]
# # Plots of the '150bp' groups in R&D58 and R&D59

# %%
rd58_150bp_unique = rd58_df[!, ["sample", "uniquely_mapped"]][1:5, :]
rd59_150bp_unique = rd59_df[!, ["sample", "uniquely_mapped"]][1:5, :]
rd_150bp_unique_merge = hcat(rd58_150bp_unique, rd59_150bp_unique, makeunique=true)

unique1 = parse.(Float64, replace.(rd_150bp_unique_merge[!, "uniquely_mapped"], r"%" => ""))
unique2 = parse.(Float64, replace.(rd_150bp_unique_merge[!, "uniquely_mapped_1"], r"%" => ""))

plot([unique1, unique2], 
    marker = :circle,
    xlabel = "RNA input", 
    ylabel = "Uniquely mapped (%)", 
    ylim = (0, 100),
    label = ["RD58" "RD59"],
    size=(900,700),
    legend=:right,
    legendtitle = "150bp",
    xrotation = 45,
    xticks = (1:5, ("10pg", "100pg", "500pg", "1ng", "10ng/25ng")),
    xtickfontsize=12, ytickfontsize=12,
    guidefont=font(15),
    m = (1, 10)
)

# %%
rd58_150bp_duplicate = rd58_df[!, ["sample", "duplicate_rate"]][1:5, :]
rd59_150bp_duplicate = rd59_df[!, ["sample", "duplicate_rate"]][1:5, :]
rd_150bp_duplicate_merge = hcat(rd58_150bp_duplicate, rd59_150bp_duplicate, makeunique=true)

duplicate1 = parse.(Float64, replace.(rd_150bp_duplicate_merge[!, "duplicate_rate"], r"%" => ""))
duplicate2 = parse.(Float64, replace.(rd_150bp_duplicate_merge[!, "duplicate_rate_1"], r"%" => ""))

plot([duplicate1, duplicate2], 
    marker = :circle,
    xlabel = "RNA input", 
    ylabel = "Duplicate rate (%)", 
    ylim = (0, 100),
    label = ["RD58" "RD59"],
    legend=:right,
    legendtitle = "150bp",
    size=(900,700),
    xrotation = 45,
    xticks = (1:5, ("10pg", "100pg", "500pg", "1ng", "10ng/25ng")),
    xtickfontsize=12, ytickfontsize=12,
    guidefont=font(15),
    m = (1, 10)
)

# %%
rd58_150bp_gene = rd58_df[!, ["sample", "protein-coding_gene_mapped(21859)"]][1:5, :]
rd59_150bp_gene = rd59_df[!, ["sample", "protein-coding_gene_mapped(19954)"]][1:5, :]
rd_150bp_gene_merge = hcat(rd58_150bp_gene, rd59_150bp_gene, makeunique=true)

gene1 = rd_150bp_gene_merge[!, "protein-coding_gene_mapped(21859)"]
gene2 = rd_150bp_gene_merge[!, "protein-coding_gene_mapped(19954)"]

plot([gene1, gene2], 
    marker = :circle,
    xlabel = "RNA input", 
    ylabel = "Total genes detected", 
    label = ["RD58" "RD59"],
    legend=:right,
    legendtitle = "150bp",
    size=(900,700),
    xrotation = 45,
    xticks = (1:5, ("10pg", "100pg", "500pg", "1ng", "10ng/25ng")),
    xtickfontsize=12, ytickfontsize=12,
    guidefont=font(15),
    m = (1, 10)
)

# %% [markdown]
# # Plots of the '50bp' groups in R&D58 and R&D59

# %%
rd58_50bp_gene = rd58_df[!, ["sample", "treatment", "input", "protein-coding_gene_mapped(21859)"]][6:end, :]
rd59_50bp_gene = rd59_df[!, ["sample", "treatment", "input", "protein-coding_gene_mapped(19954)"]][6:end, :]
rd_50bp_gene_merge = hcat(rd58_50bp_gene, rd59_50bp_gene, makeunique=true)
# Out:
# 20×8 DataFrame
#  Row │ sample                 treatment  input   protein-coding_gene_mapped(21 ⋯
#      │ String?                String     String  Union{Missing, Int64}         ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ RD58-10pg_S6_50bp      50bp       10pg                                1 ⋯
#    2 │ RD58-100pg_S7_50bp     50bp       100pg                               1
#    3 │ RD58-500pg_S8_50bp     50bp       500pg                               1
#    4 │ RD58-1ng_S9_50bp       50bp       1ng                                 1
#    5 │ RD58-10ng_S10_50bp     50bp       10ng                                1 ⋯
#    6 │ RD58-10pg_S6_50bp_1M   50bp-1M    10pg                                1
#    7 │ RD58-100pg_S7_50bp_1M  50bp-1M    100pg                               1
#    8 │ RD58-500pg_S8_50bp_1M  50bp-1M    500pg                               1
#    9 │ RD58-1ng_S9_50bp_1M    50bp-1M    1ng                                 1 ⋯
#   10 │ RD58-10ng_S10_50bp_1M  50bp-1M    10ng                                1
#   11 │ RD58-10pg_S6_50bp_2M   50bp-2M    10pg                                1
#   12 │ RD58-100pg_S7_50bp_2M  50bp-2M    100pg                               1
#   13 │ RD58-500pg_S8_50bp_2M  50bp-2M    500pg                               1 ⋯
#   14 │ RD58-1ng_S9_50bp_2M    50bp-2M    1ng                                 1
#   15 │ RD58-10ng_S10_50bp_2M  50bp-2M    10ng                                1
#   16 │ RD58-10pg_S6_50bp_5M   50bp-5M    10pg                              mis
#   17 │ RD58-100pg_S7_50bp_5M  50bp-5M    100pg                               1 ⋯
#   18 │ RD58-500pg_S8_50bp_5M  50bp-5M    500pg                               1
#   19 │ RD58-1ng_S9_50bp_5M    50bp-5M    1ng                                 1
#   20 │ RD58-10ng_S10_50bp_5M  50bp-5M    10ng                                1
#                                                                5 columns omitted

# %%
#pyplot()
newColumn1 = rd_50bp_gene_merge[!, "protein-coding_gene_mapped(21859)"]
newColumn2 = rd_50bp_gene_merge[!, "protein-coding_gene_mapped(19954)"]

@df rd_50bp_gene_merge plot(inputs,
    [newColumn1[1:5], newColumn1[6:10], newColumn1[11:15], newColumn1[16:20]],
    label = ["RD58" "RD58-1M" "RD58-2M" "RD58-5M"],
    shape = [:star5 :utriangle :rect :diamond ],
    legend = :outerright,
    size=(900,700),
    xlabel = "RNA input", 
    ylabel = "Total genes detected",
    xtickfontsize=12, ytickfontsize=12,
    guidefont=font(15),
    m = (1, 10)
)

@df rd_50bp_gene_merge plot!(inputs,
    [newColumn2[1:5], newColumn2[6:10], newColumn2[11:15], newColumn2[16:20]],
    label = ["RD59" "RD59-1M" "RD59-2M" "RD59-5M"],
    shape = [:star5 :utriangle :rect :diamond ],
    #markercolor = :transparent,
    legend = :outerright,
    legendtitle = "50bp",
    size=(900,700),
    xlabel = "RNA input", 
    ylabel = "Total genes detected",
    xtickfontsize=12, ytickfontsize=12,
    guidefont=font(15),
    m = (1, 10)
)
